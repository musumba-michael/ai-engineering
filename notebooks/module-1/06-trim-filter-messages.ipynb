# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/trim-filter-messages.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239435-lesson-4-trim-and-filter-messages)

# %% [markdown]
# # Filtering and trimming messages
#
# ## Review
#
# Now, we have a deeper understanding of a few things:
#
# * How to customize the graph state schema
# * How to define custom state reducers
# * How to use multiple graph state schemas
#
# ## Goals
#
# Now, we can start using these concepts with models in LangGraph!
#
# In the next few sessions, we'll build towards a chatbot that has long-term memory.
#
# Because our chatbot will use messages, let's first talk a bit more about advanced ways to work with messages in graph state.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# We'll use [LangSmith](https://docs.langchain.com/langsmith/home) for [tracing](https://docs.langchain.com/langsmith/observability-concepts).
#
# We'll log to the project set by `LANGSMITH_PROJECT` in the repo-root `.env`, which is `ai-engineering`.

# %% [markdown]
# ## Messages as state
#
# First, let's define some messages.

# %%
from pprint import pprint
from langchain_core.messages import AIMessage, HumanMessage
messages = [AIMessage(f"So you said you were researching ocean mammals?", name="Bot")]
messages.append(HumanMessage(f"Yes, I know about whales. But what others should I learn about?", name="Lance"))

for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?

# %% [markdown]
# Recall we can pass them to a chat model.

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-20b")
llm.invoke(messages)
# Out:
# AIMessage(content='Great! If you’re already familiar with whales, you’ve got a solid foundation in the Cetacea order. From there, you can branch out into a variety of other fascinating marine mammals that share the ocean (or even the open water) but belong to different families or orders. Below is a “road‑map” of the most interesting groups, a few standout species in each, and why they’re worth a deeper look.\n\n| Group | Key Families/Orders | Representative Species | Why It’s Fascinating | Quick Conservation Note |\n|-------|--------------------|------------------------|----------------------|--------------------------|\n| **Dolphins & Porpoises** | *Delphinidae* (dolphins), *Phocoenidae* (porpoises) | **Bottlenose dolphin** (*Tursiops truncatus*), **Harbour porpoise** (*Phocoena phocoena*) | Highly intelligent, complex social structures, acoustic communication, and human interactions (e.g., marine parks, dolphin‑watching). | Many dolphin species are listed as “Near Threatened” or “Vulnerable.” Harbor porpoises are “Near Threatened.” |\n| **Pinnipeds** | *Otariidae* (eared seals), *Phocidae* (earless seals), *Odobenidae* (walrus) | **California sea lion** (*Zalophus californianus*), **Harbour seal** (*Phoca vitulina*), **Walrus** (*Odobenus rosmarus*) | Semi‑aquatic lifestyles, remarkable breeding colonies, and iconic “seal” imagery in media. | Walruses are “Vulnerable.” Many seal species face threats from climate change and hunting. |\n| **Sirenians** | *Sirenia* (manatees, dugongs) | **West Indian manatee** (*Trichechus manatus*), **Dugong** (*Dugong dugon*) | Ancient, slow‑moving herbivores that help maintain seagrass ecosystems; unique “swimming” adaptations. | Both are “Vulnerable.” Habitat loss, boat collisions, and hunting are major concerns. |\n| **Beaked Whales** | *Ziphiidae* | **Cuvier’s beaked whale** (*Ziphius cavirostris*), **Ginkgo-toothed beaked whale** (*Mesoplodon ginkgodens*) | Deep‑divers, mysterious, rarely seen; important for understanding deep‑sea ecology. | Many are “Data Deficient,” but bycatch and ship strikes threaten them. |\n| **Sea Cows** (Sirenians) | See Sirenians | — | — | — |\n| **Mysticetes** (Baleen whales) | *Balaenopteridae*, *Eschrichtiidae* | **Humpback whale** (*Megaptera novaeangliae*), **Gray whale** (*Eschrichtius robustus*) | Largest of the ocean giants, complex songs, and impressive migratory routes. | Humpbacks are “Least Concern” but still face threats from entanglement and ship strikes. |\n| **Odontocetes** (Toothed whales) | *Delphinidae*, *Physeteridae*, *Kogiidae*, etc. | **Sperm whale** (*Physeter macrocephalus*), **Killer whale** (*Orcinus orca*) | Diverse feeding strategies (e.g., deep‑diving sperm whales, apex predators like orcas). | Sperm whales are “Vulnerable.” Orcas are “Data Deficient” but some populations are threatened. |\n| **Seabirds & Seals** | — | — | — | — |\n\n---\n\n## How to Dive Deeper\n\n### 1. **Pick a Species and Read Its “Life History”**\n- **Example**: *Bottlenose dolphin* – learn about its social pods, tool use, and the “whale song” phenomenon.\n- **Resource**: *The Dolphin Book* by Jane Goodall or *Whale Songs* by John B. McCowan.\n\n### 2. **Explore Their Ecological Roles**\n- **Seals**: Keystone predators on kelp forests.\n- **Manatees**: “Living fossils” that keep seagrass beds healthy.\n- **Whales**: Nutrient cycling via “whale falls” and “whale poop” fertilization.\n\n### 3. **Understand Threats & Conservation Efforts**\n- **Human Impacts**: Bycatch, habitat loss, pollution, climate change, and tourism.\n- **Protection Measures**: International agreements (e.g., CMS, CITES), marine protected areas, and community‑based conservation.\n\n### 4. **Visit Online Databases & Journals**\n- **IUCN Red List**: Up‑to‑date conservation status.\n- **Marine Mammal Commission**: Reports on marine mammal research.\n- **Journal of Marine Biology**: Peer‑reviewed research articles.\n\n### 5. **Get Hands‑On (If Possible)**\n- **Field Trips**: Join a whale‑watch ...

# %% [markdown]
# We can run our chat model in a simple graph with `MessagesState`.

# %%
from IPython.display import Image, display
from langgraph.graph import MessagesState
from langgraph.graph import StateGraph, START, END

# Node
def chat_model_node(state: MessagesState):
    return {"messages": llm.invoke(state["messages"])}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# ### Quick‑Start Guide: “Beyond the Whale”
# Below is a curated list of marine mammals that are often overlooked but are fascinating, ecologically important, and rich with research opportunities. For each group I’ve highlighted a few key species, what makes them unique, and why they’re worth studying. Feel free to pick one or mix a few—there’s plenty of room for a comparative or interdisciplinary project!
#
# | Group | Representative Species | Why It’s Interesting | Key Research Themes | Conservation Note |
# |-------|------------------------|----------------------|--------------------|-------------------|
# | **Delphinidae (Dolphins & Porpoises)** | *Tursiops truncatus* (Bottlenose dolphin), *Phocoena phocoena* (Harbor porpoise) | Highly intelligent, complex social systems, acoustic communication | • Vocalization & echolocation<br>• Tool use & cultural transmission<br>• Human–wildlife interactions | Bottlenose dolphins are “CITES Appendix I” in some regions; harbor porpoises are vulnerable in the North Atlantic. |
# | **Pinnipedia (Seals, Sea Lions, Walruses)** | *Eumetopias jubatus* (Steller sea lion), *Odobenus rosmarus* (Walrus), *Phoca vitulina* (Harbor seal) | Diverse foraging strategies, seasonal migrations, strong pelage adaptations | • Physiological adaptations to cold<br>• Climate‑change impacts on haul‑out sites<br>• Human impacts (fishing, oil spills) | Steller sea lion is endangered; walrus populations are fluctuating due to sea‑ice loss. |
# | **Sirenia (Manatees & Dugongs)** | *Trichechus manatus* (West Indian manatee), *Dugong dugon* (Dugong) | Slow‑moving herbivores, keystone species in seagrass beds, unique reproductive biology | • Seagrass ecosystem dynamics<br>• Hydrocarbon‑related mortality<br>• Genetic diversity & connectivity | Both species are vulnerable; dugongs face high mortality from fishing gear. |
# | **Mysticeti (Baleen Whales)** | *Balaenoptera musculus* (Blue whale), *Eschrichtius robustus* (Gray whale) | Massive body size, long‑distance migrations, baleen filtration | • Acoustic monitoring of migration<br>• Nutrient cycling & “whale pump” effect<br>• Climate change on prey distribution | Blue whales are near‑endangered; gray whales are recovering but still protected. |
# | **Odontoceti (Toothed Whales)** | *Orcinus orca* (Killer whale), *Globicephala melas* (Long‑finned pilot whale) | Complex social hierarchies, varied diets, cultural “ecotypes” | • Ecological niche partitioning<br>• Anthropogenic noise impact<br>• Conservation genetics | Orca populations vary globally; some are protected under national legislation. |
# | **Other Notable Groups** | *Monodon monoceros* (Narwhal), *Lagenorhynchus acutus* (Leopard seal), *Hydrolagus spp.* (Ratfish – a jawless “living fossil”) | Rarely studied, unique evolutionary histories | • Arctic adaptations<br>• Deep‑sea physiology<br>• Evolutionary genomics | Many are data‑deficient; conservation status often unclear. |
#
# ---
#
# ## How to Pick Your Focus
#
# | Question | What it Reveals |
# |----------|-----------------|
# | **What’s your background?** | Biology, ecology, physics, data science, etc. |
# | **Do you prefer field vs. lab work?** | Seals & sea lions (field), dolphins (both), sirenians (field). |
# | **Are you interested in a specific conservation issue?** | Climate change, by‑catch, noise pollution, habitat loss. |
# | **Do you want to work with existing data or generate new data?** | Acoustic datasets, satellite telemetry, genetic samples. |
# | **Is there a local species you can access?** | Coastal seals, harbor porpoises, manatees in Florida. |
#
# ---
#
# ## Suggested Research Projects (one‑to‑two‑year scope)
#
# | Project | Core Idea | Data Sources | Potential Outcomes |
# |---------|-----------|--------------|--------------------|
# | **Acoustic Mapping of Harbor Porpoise Populations** | Use passive acoustic monitoring to estimate density & distribution. | Hydrophones, satellite tags, existing acoustic libraries. | Baseline population metrics; impact assessment of shipping noise. |
# | **Thermoregulation in Steller Sea Lions** | Measure skin temperature & blubber thickness across seasons. | Field thermography, core body temperature loggers. | Insights into energy budgets; implications for sea‑ice loss. |
# | **Seagrass‑Manatee Interaction Dynamics** | Quantify grazing rates and seagrass recovery. | Field surveys, remote sensing, stable isotope analysis. | Management recommendations for coastal development. |
# | **Genomic Adaptations to Cold in Walruses** | Identify genes linked to skin thickness, blubber composition. | DNA sequencing, comparative genomics. | Understanding evolutionary responses to Arctic warming. |
# | **Cultural Transmission in Orca “Ecotypes”** | Compare vocal repertoires across populations. | Audio recordings, machine‑learning clustering. | Clarify the role of culture in population resilience. |
#
# ---
#
# ## Resources & Where to Start
#
# | Resource | What It Offers | How to Use |
# |----------|----------------|------------|
# | **NOAA Marine Mammal Center** | Data on strandings, health records, public education | Download datasets; collaborate on field studies. |
# | **IUCN Red List** | Conservation status, threat assessments | Identify priority species; track population trends. |
# | **Marine Mammal Database (MMDB)** | Acoustic, telemetry, and ecological data | Filter by species, region, or data type. |
# | **Global Biodiversity Information Facility (GBIF)** | Occurrence records (GPS coordinates, dates) | Map distribution; perform species‑distribution modeling. |
# | **Open Science Framework (OSF)** | Repository for protocols, raw data, analysis scripts | Share your workflow; get feedback from the community. |
# | **Journal Clubs & Conferences** | Latest research, networking | Attend *Mammal Review*, *Journal of Marine Mammalogy*, *IUCN Marine Mammal Specialist Group* meetings. |
#
# ---
#
# ## Tips for a Successful Project
#
# 1. **Define a clear, testable hypothesis** – e.g., “Sea‑ice extent predicts the distribution of Steller sea lions in the Bering Sea.”
# 2. **Use open‑source tools** – R, Python, GIS, and acoustic analysis packages (e.g., *seewave*, *Raven*).
# 3. **Collaborate early** – Reach out to local universities, NOAA field stations, or NGOs.
# 4. **Secure funding** – Small grants (NSF REU, NOAA Marine Mammal Conservation Grant) or crowd‑source platforms (Kickstarter for marine conservation).
# 5. **Publish in open‑access journals** – *Marine Biology*, *PLoS ONE*, *Frontiers in Marine Science* to maximize visibility.
#
# ---
#
# ### Final Thought
#
# The marine mammal world is a mosaic of **intelligence, resilience, and vulnerability**. Whether you’re drawn to the social complexity of dolphins, the ecological role of sirenians, or the physiological marvels of seals, each group offers a unique window into how life adapts to the ocean’s extremes. Pick a species that excites you, align it with a pressing research question, and you’ll be on your way to contributing valuable knowledge to marine science and conservation.
#
# Good luck, and let me know if you’d like deeper dives into any specific species, methodologies, or funding avenues!

# %% [markdown]
# ## Reducer
#
# A practical challenge when working with messages is managing long-running conversations.
#
# Long-running conversations result in high token usage and latency if we are not careful, because we pass a growing list of messages to the model.
#
# We have a few ways to address this.
#
# First, recall the trick we saw using `RemoveMessage` and the `add_messages` reducer.

# %%
from langchain_core.messages import RemoveMessage

# Nodes
def filter_messages(state: MessagesState):
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"messages": delete_messages}

def chat_model_node(state: MessagesState):    
    return {"messages": [llm.invoke(state["messages"])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("filter", filter_messages)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "filter")
builder.add_edge("filter", "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
# Message list with a preamble
messages = [AIMessage("Hi.", name="Bot", id="1")]
messages.append(HumanMessage("Hi.", name="Lance", id="2"))
messages.append(AIMessage("So you said you were researching ocean mammals?", name="Bot", id="3"))
messages.append(HumanMessage("Yes, I know about whales. But what others should I learn about?", name="Lance", id="4"))

# Invoke
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# Here’s a quick “road‑map” of the other ocean mammals you can dive into after whales. I’ve grouped them by family, added a one‑sentence hook, and a couple of cool facts or research angles you might want to explore.
#
# | Family / Group | Key Species | Hook / Why It’s Fascinating | Quick Research Angles |
# |----------------|-------------|-----------------------------|------------------------|
# | **Delphinidae (Dolphins)** | Bottlenose dolphin, common dolphin, short‑beaked common dolphin | Extremely intelligent, use complex vocal “signature whistles.” | Acoustic communication, social learning, tool use (e.g., fish‑stick hunting). |
# | **Phocoenidae (Porpoises)** | Harbor porpoise, vaquita | Less studied, but crucial for understanding marine mammal evolution. | Population monitoring, acoustic adaptations to murkier waters. |
# | **Killer Whale (Orcinus orca)** | Orca | A true “killer whale” with distinct ecotypes (fish‑eaters, mammal‑eaters, etc.). | Ecotype genetics, cultural transmission of hunting techniques. |
# | **Pinnipeds (Seals & Sea Lions)** | Harbor seal, California sea lion, elephant seal | Semi‑aquatic, excellent for studying terrestrial‑aquatic transitions. | Thermoregulation in cold waters, haul‑out site selection, human‑seal interactions. |
# | **Otariidae (Sea Lions)** | Steller sea lion, Galápagos sea lion | Larger, more agile, and more social than true seals. | Migration patterns, response to climate change. |
# | **Phocidae (True Seals)** | Weddell seal, ringed seal, harp seal | Fully adapted to ice; some species breed on land. | Ice‑break adaptation, polar bear interactions, climate‑driven habitat shifts. |
# | **Sirenians (Manatees & Dugongs)** | West Indian manatee, dugong | Ancient “sea cows” – slow‑moving but ecologically vital. | Grazing impact on seagrass beds, anthropogenic threats (boat strikes). |
# | **Cetotheriidae (Beaked Whales)** | Cuvier’s beaked whale, Blainville’s beaked whale | Deep‑diving specialists; little is known about them. | Deep‑sea acoustic monitoring, migration routes. |
# | **Mysticetes (Baleen Whales)** | Humpback whale, blue whale, gray whale | The largest animals on Earth; huge ecological roles. | Baleen feeding mechanics, baleen plate growth rates, migratory connectivity. |
# | **Odontocetes (Toothed Whales)** | Sperm whale, pygmy sperm whale, pygmy sperm whale | Powerful echolocators, deep‑diving. | Deep‑sea sonar, reproductive biology in the deep. |
# | **Marine Rodents?** | *No true marine rodents* | (Just a joke!) | Focus on the groups above instead. |
# | **Other marine mammals** | **Marine otter** (Neogale vison), **sea mink** (Neogale vison) | Rarely studied, but important for coastal ecosystems. | Habitat use, diet, conservation status. |
#
# ### How to Structure Your Learning
#
# 1. **Start with the “big guys”**
#    * Whales (baleen & toothed) → Orcas → Dolphins.
#    * These groups are well‑documented and give you a foundation in marine mammal biology.
#
# 2. **Move to the “pinniped” cluster**
#    * Seals, sea lions, walruses.
#    * Look at their semi‑aquatic life and how they’ve adapted to different temperatures.
#
# 3. **Explore the “sirenians”**
#    * Manatees and dugongs are the only living relatives of ancient “sea cows.”
#    * They’re great case studies for conservation biology.
#
# 4. **Finish with the niche groups**
#    * Porpoises, beaked whales, marine otters.
#    * These species often fill gaps in our ecological understanding.
#
# ### Resources to Get You Started
#
# | Type | Example | Why It’s Useful |
# |------|---------|-----------------|
# | **Books** | *“Marine Mammals of the World: A Comprehensive Guide”* by R. L. C. | In‑depth species profiles. |
# | | *“Dolphins: The Science of the Ocean’s Most Intelligent Mammals”* by R. K. | Focus on dolphin cognition. |
# | **Documentaries** | *“Blue Planet II”* (BBC) – episodes on whales & dolphins | Visual context + expert interviews. |
# | **Academic Journals** | *Journal of Cetacean Research*, *Marine Mammal Science* | Latest research papers. |
# | **Online Databases** | *IUCN Red List*, *Marine Mammal Database* (MMDB) | Conservation status, distribution maps. |
# | **Citizen Science Projects** | *Whale Watching & Tracking (WWT)*, *Pinniped Monitoring* | Data collection, real‑time learning. |
#
# ### Quick “Starter Projects”
#
# | Project | What It Involves | Why It’s Great for Learning |
# |---------|------------------|-----------------------------|
# | **Acoustic Monitoring** | Deploy hydrophones to record dolphin whistles or whale songs. | Hands‑on experience with bioacoustics. |
# | **Population Estimation** | Use photo‑identification to estimate seal numbers on a haul‑out site. | Practical stats & fieldwork. |
# | **Habitat Modeling** | Build a GIS model of manatee habitats relative to water temperature. | Integrates ecology, GIS, climate science. |
# | **Literature Review** | Summarize current knowledge on beaked whale migration. | Develops research‑synthesis skills. |
#
# Feel free to let me know which group intrigues you the most, and I can dive deeper into specific species, research questions, or learning resources!

# %% [markdown]
# ## Filtering messages
#
# If you don't need or want to modify the graph state, you can just filter the messages you pass to the chat model.
#
# For example, just pass in a filtered list: `llm.invoke(messages[-1:])` to the model.

# %%
# Node
def chat_model_node(state: MessagesState):
    return {"messages": [llm.invoke(state["messages"][-1:])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# Let's take our existing list of messages, append the above LLM response, and append a follow-up question.

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me more about Narwhals!", name="Lance"))

# %%
for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# Here’s a quick “road‑map” of the other ocean mammals you can dive into after whales. I’ve grouped them by family, added a one‑sentence hook, and a couple of cool facts or research angles you might want to explore.
#
# | Family / Group | Key Species | Hook / Why It’s Fascinating | Quick Research Angles |
# |----------------|-------------|-----------------------------|------------------------|
# | **Delphinidae (Dolphins)** | Bottlenose dolphin, common dolphin, short‑beaked common dolphin | Extremely intelligent, use complex vocal “signature whistles.” | Acoustic communication, social learning, tool use (e.g., fish‑stick hunting). |
# | **Phocoenidae (Porpoises)** | Harbor porpoise, vaquita | Less studied, but crucial for understanding marine mammal evolution. | Population monitoring, acoustic adaptations to murkier waters. |
# | **Killer Whale (Orcinus orca)** | Orca | A true “killer whale” with distinct ecotypes (fish‑eaters, mammal‑eaters, etc.). | Ecotype genetics, cultural transmission of hunting techniques. |
# | **Pinnipeds (Seals & Sea Lions)** | Harbor seal, California sea lion, elephant seal | Semi‑aquatic, excellent for studying terrestrial‑aquatic transitions. | Thermoregulation in cold waters, haul‑out site selection, human‑seal interactions. |
# | **Otariidae (Sea Lions)** | Steller sea lion, Galápagos sea lion | Larger, more agile, and more social than true seals. | Migration patterns, response to climate change. |
# | **Phocidae (True Seals)** | Weddell seal, ringed seal, harp seal | Fully adapted to ice; some species breed on land. | Ice‑break adaptation, polar bear interactions, climate‑driven habitat shifts. |
# | **Sirenians (Manatees & Dugongs)** | West Indian manatee, dugong | Ancient “sea cows” – slow‑moving but ecologically vital. | Grazing impact on seagrass beds, anthropogenic threats (boat strikes). |
# | **Cetotheriidae (Beaked Whales)** | Cuvier’s beaked whale, Blainville’s beaked whale | Deep‑diving specialists; little is known about them. | Deep‑sea acoustic monitoring, migration routes. |
# | **Mysticetes (Baleen Whales)** | Humpback whale, blue whale, gray whale | The largest animals on Earth; huge ecological roles. | Baleen feeding mechanics, baleen plate growth rates, migratory connectivity. |
# | **Odontocetes (Toothed Whales)** | Sperm whale, pygmy sperm whale, pygmy sperm whale | Powerful echolocators, deep‑diving. | Deep‑sea sonar, reproductive biology in the deep. |
# | **Marine Rodents?** | *No true marine rodents* | (Just a joke!) | Focus on the groups above instead. |
# | **Other marine mammals** | **Marine otter** (Neogale vison), **sea mink** (Neogale vison) | Rarely studied, but important for coastal ecosystems. | Habitat use, diet, conservation status. |
#
# ### How to Structure Your Learning
#
# 1. **Start with the “big guys”**
#    * Whales (baleen & toothed) → Orcas → Dolphins.
#    * These groups are well‑documented and give you a foundation in marine mammal biology.
#
# 2. **Move to the “pinniped” cluster**
#    * Seals, sea lions, walruses.
#    * Look at their semi‑aquatic life and how they’ve adapted to different temperatures.
#
# 3. **Explore the “sirenians”**
#    * Manatees and dugongs are the only living relatives of ancient “sea cows.”
#    * They’re great case studies for conservation biology.
#
# 4. **Finish with the niche groups**
#    * Porpoises, beaked whales, marine otters.
#    * These species often fill gaps in our ecological understanding.
#
# ### Resources to Get You Started
#
# | Type | Example | Why It’s Useful |
# |------|---------|-----------------|
# | **Books** | *“Marine Mammals of the World: A Comprehensive Guide”* by R. L. C. | In‑depth species profiles. |
# | | *“Dolphins: The Science of the Ocean’s Most Intelligent Mammals”* by R. K. | Focus on dolphin cognition. |
# | **Documentaries** | *“Blue Planet II”* (BBC) – episodes on whales & dolphins | Visual context + expert interviews. |
# | **Academic Journals** | *Journal of Cetacean Research*, *Marine Mammal Science* | Latest research papers. |
# | **Online Databases** | *IUCN Red List*, *Marine Mammal Database* (MMDB) | Conservation status, distribution maps. |
# | **Citizen Science Projects** | *Whale Watching & Tracking (WWT)*, *Pinniped Monitoring* | Data collection, real‑time learning. |
#
# ### Quick “Starter Projects”
#
# | Project | What It Involves | Why It’s Great for Learning |
# |---------|------------------|-----------------------------|
# | **Acoustic Monitoring** | Deploy hydrophones to record dolphin whistles or whale songs. | Hands‑on experience with bioacoustics. |
# | **Population Estimation** | Use photo‑identification to estimate seal numbers on a haul‑out site. | Practical stats & fieldwork. |
# | **Habitat Modeling** | Build a GIS model of manatee habitats relative to water temperature. | Integrates ecology, GIS, climate science. |
# | **Literature Review** | Summarize current knowledge on beaked whale migration. | Develops research‑synthesis skills. |
#
# Feel free to let me know which group intrigues you the most, and I can dive deeper into specific species, research questions, or learning resources!
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!

# %%
# Invoke, using message filtering
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# Here’s a quick “road‑map” of the other ocean mammals you can dive into after whales. I’ve grouped them by family, added a one‑sentence hook, and a couple of cool facts or research angles you might want to explore.
#
# | Family / Group | Key Species | Hook / Why It’s Fascinating | Quick Research Angles |
# |----------------|-------------|-----------------------------|------------------------|
# | **Delphinidae (Dolphins)** | Bottlenose dolphin, common dolphin, short‑beaked common dolphin | Extremely intelligent, use complex vocal “signature whistles.” | Acoustic communication, social learning, tool use (e.g., fish‑stick hunting). |
# | **Phocoenidae (Porpoises)** | Harbor porpoise, vaquita | Less studied, but crucial for understanding marine mammal evolution. | Population monitoring, acoustic adaptations to murkier waters. |
# | **Killer Whale (Orcinus orca)** | Orca | A true “killer whale” with distinct ecotypes (fish‑eaters, mammal‑eaters, etc.). | Ecotype genetics, cultural transmission of hunting techniques. |
# | **Pinnipeds (Seals & Sea Lions)** | Harbor seal, California sea lion, elephant seal | Semi‑aquatic, excellent for studying terrestrial‑aquatic transitions. | Thermoregulation in cold waters, haul‑out site selection, human‑seal interactions. |
# | **Otariidae (Sea Lions)** | Steller sea lion, Galápagos sea lion | Larger, more agile, and more social than true seals. | Migration patterns, response to climate change. |
# | **Phocidae (True Seals)** | Weddell seal, ringed seal, harp seal | Fully adapted to ice; some species breed on land. | Ice‑break adaptation, polar bear interactions, climate‑driven habitat shifts. |
# | **Sirenians (Manatees & Dugongs)** | West Indian manatee, dugong | Ancient “sea cows” – slow‑moving but ecologically vital. | Grazing impact on seagrass beds, anthropogenic threats (boat strikes). |
# | **Cetotheriidae (Beaked Whales)** | Cuvier’s beaked whale, Blainville’s beaked whale | Deep‑diving specialists; little is known about them. | Deep‑sea acoustic monitoring, migration routes. |
# | **Mysticetes (Baleen Whales)** | Humpback whale, blue whale, gray whale | The largest animals on Earth; huge ecological roles. | Baleen feeding mechanics, baleen plate growth rates, migratory connectivity. |
# | **Odontocetes (Toothed Whales)** | Sperm whale, pygmy sperm whale, pygmy sperm whale | Powerful echolocators, deep‑diving. | Deep‑sea sonar, reproductive biology in the deep. |
# | **Marine Rodents?** | *No true marine rodents* | (Just a joke!) | Focus on the groups above instead. |
# | **Other marine mammals** | **Marine otter** (Neogale vison), **sea mink** (Neogale vison) | Rarely studied, but important for coastal ecosystems. | Habitat use, diet, conservation status. |
#
# ### How to Structure Your Learning
#
# 1. **Start with the “big guys”**
#    * Whales (baleen & toothed) → Orcas → Dolphins.
#    * These groups are well‑documented and give you a foundation in marine mammal biology.
#
# 2. **Move to the “pinniped” cluster**
#    * Seals, sea lions, walruses.
#    * Look at their semi‑aquatic life and how they’ve adapted to different temperatures.
#
# 3. **Explore the “sirenians”**
#    * Manatees and dugongs are the only living relatives of ancient “sea cows.”
#    * They’re great case studies for conservation biology.
#
# 4. **Finish with the niche groups**
#    * Porpoises, beaked whales, marine otters.
#    * These species often fill gaps in our ecological understanding.
#
# ### Resources to Get You Started
#
# | Type | Example | Why It’s Useful |
# |------|---------|-----------------|
# | **Books** | *“Marine Mammals of the World: A Comprehensive Guide”* by R. L. C. | In‑depth species profiles. |
# | | *“Dolphins: The Science of the Ocean’s Most Intelligent Mammals”* by R. K. | Focus on dolphin cognition. |
# | **Documentaries** | *“Blue Planet II”* (BBC) – episodes on whales & dolphins | Visual context + expert interviews. |
# | **Academic Journals** | *Journal of Cetacean Research*, *Marine Mammal Science* | Latest research papers. |
# | **Online Databases** | *IUCN Red List*, *Marine Mammal Database* (MMDB) | Conservation status, distribution maps. |
# | **Citizen Science Projects** | *Whale Watching & Tracking (WWT)*, *Pinniped Monitoring* | Data collection, real‑time learning. |
#
# ### Quick “Starter Projects”
#
# | Project | What It Involves | Why It’s Great for Learning |
# |---------|------------------|-----------------------------|
# | **Acoustic Monitoring** | Deploy hydrophones to record dolphin whistles or whale songs. | Hands‑on experience with bioacoustics. |
# | **Population Estimation** | Use photo‑identification to estimate seal numbers on a haul‑out site. | Practical stats & fieldwork. |
# | **Habitat Modeling** | Build a GIS model of manatee habitats relative to water temperature. | Integrates ecology, GIS, climate science. |
# | **Literature Review** | Summarize current knowledge on beaked whale migration. | Develops research‑synthesis skills. |
#
# Feel free to let me know which group intrigues you the most, and I can dive deeper into specific species, research questions, or learning resources!
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!
# ================================== Ai Message ==================================
#
# **Narwhals (Monodon monoceros)** – the “unicorns of the sea”
#
# | Category | Details |
# |----------|---------|
# | **Taxonomy** | Kingdom: Animalia – Phylum: Chordata – Class: Mammalia – Order: Cetacea – Suborder: Odontoceti – Family: Monodontidae – Genus: *Monodon* – Species: *Monodon monoceros* |
# | **Common names** | Narwhal, Arctic whale, “unicorn of the sea” |
# | **Range** | Circumpolar Arctic: Greenland, Canada, Norway, Russia, and the U.S. (Alaska) |
# | **Habitat** | Seals, sea ice, and shallow coastal waters; they prefer the ice edge and sometimes travel into the open ocean. |
# | **Size** | 4.5–5.5 m (15–18 ft) long, 1.5–2.5 t (3,300–5,500 lb) |
# | **Tusk** | A single, spiral, “unicorn‑like” tusk up to 3 m (10 ft) long. It is an elongated, ever‑growing upper‑left canine. The tusk contains thousands of sensory nerve endings that help detect pressure changes, temperature, and possibly chemical cues in the water. |
# | **Diet** | Predominantly fish (e.g., Arctic cod, capelin), squid, shrimp, and sometimes crustaceans. They hunt by echolocation, emitting high‑frequency clicks and listening for the returning echoes. |
# | **Social behavior** | Generally solitary or in small pods of 2–6 individuals. They are less gregarious than many other cetaceans, but they do form loose groups, especially during feeding or breeding. |
# | **Reproduction** | • **Season**: Mating occurs in late summer to early fall. • **Gestation**: ~14–15 months. • **Birth**: Calves are 1.5–2 m long and weigh ~70 kg (150 lb). They nurse for 9–12 months. |
# | **Longevity** | Up to 30–40 years in the wild, with some individuals possibly living longer. |
# | **Conservation status** | **Near Threatened** (IUCN Red List). Threats include climate change (melting sea ice, altered prey distribution), oil and gas exploration, shipping traffic, and accidental capture in fishing gear. Traditional Inuit hunting is regulated and sustainable, but commercial interest in tusks (historically for jewelry and art) has also been a concern. |
# | **Cultural significance** | • In Inuit culture, the narwhal is revered; the tusk has been used in carvings, ceremonial objects, and as a symbol of wealth. • In folklore, the tusk’s “magical” properties (e.g., granting wishes, healing) have made it a subject of myth. |
# | **Interesting facts** | 1. **Echolocation range** – Narwhals can detect objects up to 200 m (656 ft) away. 2. **Deep dives** – They can dive to 1,500 m (4,900 ft) and hold their breath for up to 15–20 minutes. 3. **Tusk growth** – The tusk grows continuously, but growth rates slow with age. 4. **Sexual dimorphism** – The tusk is found only in males (though some females have a small, stubby tusk). 5. **Blubber** – Narwhals have a thick blubber layer (up to 30 cm) that insulates them in the icy waters. |
# | **Research highlights** | • Recent studies using acoustic telemetry have mapped their migration routes, showing seasonal shifts in depth and latitude. • Genetic research indicates that narwhals split into distinct populations in the eastern and western Arctic, each with slightly different ecological adaptations. |
#
# ### Quick Takeaway
# Narwhals are one of the most iconic Arctic marine mammals, famed for their long, spiraled tusk that doubles as a highly sensitive sensory organ. They thrive in the cold, icy waters of the Arctic, using sophisticated echolocation to hunt and navigate. While they are currently listed as Near Threatened, ongoing climate change and human activity pose significant risks. Conservation efforts focus on monitoring populations, regulating hunting, and protecting critical habitats from industrial development.
#
# Feel free to ask if you'd like deeper details on any specific aspect—diet, migration, or cultural history!

# %% [markdown]
# The state has all of the mesages.
#
# But, let's look at the LangSmith trace to see that the model invocation only uses the last message:
#
# https://smith.langchain.com/public/75aca3ce-ef19-4b92-94be-0178c7a660d9/r

# %% [markdown]
# ## Trim messages
#
# Another approach is to [trim messages](https://docs.langchain.com/oss/python/langgraph/add-memory#trim-messages), based upon a set number of tokens.
#
# This restricts the message history to a specified number of tokens.
#
# While filtering only returns a post-hoc subset of the messages between agents, trimming restricts the number of tokens that a chat model can use to respond.
#
# See the `trim_messages` below.

# %%
from langchain_core.messages import trim_messages

# Node
def chat_model_node(state: MessagesState):
    messages = trim_messages(
            state["messages"],
            max_tokens=100,
            strategy="last",
            token_counter="approximate",
            allow_partial=False,
        )
    return {"messages": [llm.invoke(messages)]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me where Orcas live!", name="Lance"))

# %%
# Example of trimming messages
trim_messages(
            messages,
            max_tokens=100,
            strategy="last",
            token_counter="approximate",
            allow_partial=False
        )
# Out:
# [HumanMessage(content='Tell me where Orcas live!', additional_kwargs={}, response_metadata={}, name='Lance')]

# %%
# Invoke, using message trimming in the chat_model_node 
messages_out_trim = graph.invoke({'messages': messages})

# %% [markdown]
# Let's look at the LangSmith trace to see the model invocation:
#
# https://smith.langchain.com/public/b153f7e9-f1a5-4d60-8074-f0d7ab5b42ef/r
